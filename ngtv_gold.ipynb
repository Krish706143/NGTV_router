# %%
bronze_gold_df1 = spark.read.format("delta").load(
    "abfss://silver@ngtv.dfs.core.windows.net/df_49_50_error_disable_logs_merge"
)

#bronze_gold_df1.show(100, truncate=False)

# %%
bronze_gold_df2 = spark.read.format("delta").load(
    "abfss://silver@ngtv.dfs.core.windows.net/df_erroring_link_merge"
)

#bronze_gold_df2.show(100, truncate=False)

# %%
bronze_gold_df3 = spark.read.format("delta").load(
    "abfss://silver@ngtv.dfs.core.windows.net/df_metric_log_script"
)

#bronze_gold_df3.show(100, truncate=False)
